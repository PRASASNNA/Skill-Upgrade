# %% [markdown]
# # Exploratory Data Anslysis(EDA) On a Dataset

# %% [raw]
# Task Description:
# 1.Perform exploratory data analysis on a dataset of your choice in titanic dataset.
# 2.Use Python and popular libraries(e.g.,Pandas,Matplotlib,Seaborn) for data manipulation and visualiztion.
# 3.Generate summary statistics, visualiztions, and insights from the dataset.

# %% [markdown]
# # 1.Perform exploratory data analysis on a dataset of your choice in titanic dataset

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the Dataset

# %%
# Load the Titanic dataset
titanic_df = pd.read_csv("Titanic+Data+Set.csv")
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Explore the Data

# %%
# Display the first few rows of the dataset
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Check the data types of each column
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Handle Missing Values

# %%
# Check for missing values
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Impute missing values with the mean
titanic_df['Age'].fillna(titanic_df['Age'].mean(), inplace=True)

# %%
# Handling missing values in 'Embarked' column by imputing with mode
titanic_df['Embarked'].fillna(titanic_df['Embarked'].mode()[0], inplace=True)

# %%
# Handling missing values in 'Cabin' column by creating a new category 'Unknown'
titanic_df['Cabin'].fillna('Unknown', inplace=True)

# %%
# Check if there are any missing values left
titanic_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# Save encoded data
titanic_df.to_csv("titanic.csv", index=False)

# %% [markdown]
# # 2.Use Python and popular libraries(e.g.,Pandas,Matplotlib,Seaborn) for data manipulation and visualiztion.

# %% [markdown]
# # Visualize Data Distributions.

# %%
# Visualize the distribution of numerical variables using histograms
titanic_df.hist(figsize=(10, 8))
plt.show()

# %%
# Visualize the distribution of categorical variables using count plots
sns.countplot(x='Survived', data=titanic_df)
plt.show()

# %% [markdown]
# # Explore Relationships between Variables

# %%
# Explore relationships between numerical variables using scatter plots
sns.scatterplot(x='Age', y='Fare', data=titanic_df)
plt.show()

# %%
# Explore relationships between numerical and categorical variables using box plots
sns.boxplot(x='Survived', y='Age', data=titanic_df)
plt.show()

# %%
# Explore relationships between categorical variables using stacked bar plots
sns.countplot(x='Survived', hue='Sex', data=titanic_df)
plt.show()

# %% [markdown]
# # 3.Generate summary statistics, visualiztions, and insights from the dataset

# %% [markdown]
# # Summary Statistics:

# %%
# Summary statistics of numerical variables
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Summary statistics of categorical variables
print(titanic_df.describe(include=['object']))
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      891      891
# unique                      891     2     681      148        3
# top     Braund, Mr. Owen Harris  male  347082  Unknown        S
# freq                          1   577       7      687      646

# %%
# Visualize the distribution of passengers by class
sns.countplot(x='Pclass', data=titanic_df)
plt.title('Passenger Class Distribution')
plt.show()

# %%
# Visualize the distribution of passengers by gender
sns.countplot(x='Sex', data=titanic_df)
plt.title('Passenger Gender Distribution')
plt.show()

# %%
# Visualize the distribution of passengers by survival
sns.countplot(x='Survived', data=titanic_df)
plt.title('Survival Count')
plt.show()

# %%
# Visualize the age distribution of passengers
sns.histplot(data=titanic_df, x='Age', bins=20, kde=True)
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.show()

# %%
# Visualize the survival distribution by age
sns.histplot(data=titanic_df, x='Age', hue='Survived', bins=20, kde=True, multiple='stack')
plt.title('Survival Distribution by Age')
plt.xlabel('Age')
plt.show()

# %%
# Visualize the survival distribution by gender
sns.countplot(x='Sex', hue='Survived', data=titanic_df)
plt.title('Survival Distribution by Gender')
plt.show()

# %%
# Visualize the survival distribution by passenger class
sns.countplot(x='Pclass', hue='Survived', data=titanic_df)
plt.title('Survival Distribution by Passenger Class')
plt.show()

# %% [markdown]
# # Insights

# %% [markdown]
# 1.The majority of passengers were in third class.
#
# 2.There were more male passengers than female passengers.
#
# 3.The number of passengers who did not survive is higher than the number of survivors.
#
# 4.The age distribution of passengers is skewed to the right, with a significant number of passengers in the younger age group.
#
# 5.Infants and children had a higher survival rate compared to adults.
#
# 6.Females had a higher chance of survival compared to males.
#
# 7.Passengers in first class had a higher chance of survival compared to those in second and third class.

# %% [markdown]
# These are some insights derived from summary statistics and visualizations of the Titanic dataset. Further analysis and exploration can provide more detailed insights into the factors affecting survival on the Titanic.
